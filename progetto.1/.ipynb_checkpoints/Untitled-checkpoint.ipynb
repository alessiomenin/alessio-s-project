# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Dati = pd.read_csv("DATALOG_csv.txt")

# %%
Dati = Dati.rename(columns={'18/11/2018 12:5:39': 'DataOra', 'S1':'', '33.38':'S1', 'S2':'', '38.94':'S2', 'S3':'', '10.25':'S3', 'S4':'', '35.50':'S4'  })

# %%
S1B1 = Dati.S1[0:284]
TMS1B1 = S1B1.mean()

# %%
S2B1 = Dati.S2[0:284]
TMS2B1 = S2B1.mean()

# %%
S3B1 = Dati.S3[0:284]
TMS3B1 = S3B1.mean()

# %%
S4B1 = Dati.S4[0:284]
TMS4B1 = S4B1.mean()

# %%
S1B2 = Dati.S1[283:545]
TMS1B2 = S1B2.mean()

# %%
S2B2 = Dati.S2[283:545]
TMS2B2 = S2B2.mean()

# %%
S3B2 = Dati.S3[283:545]
TMS3B2 = S3B2.mean()

# %%
S4B2 = Dati.S4[283:545]
TMS4B2 = S4B2.mean()

# %%
S1B3 = Dati.S1[544:1493]
TMS1B3 = S1B3.mean()

# %%
S2B3 = Dati.S2[544:1493]
TMS2B3 = S2B3.mean()

# %%
S3B3 = Dati.S3[544:1493]
TMS3B3 = S3B3.mean()

# %%
S4B3 = Dati.S4[544:1493]
TMS4B3 = S4B3.mean()

# %%
GB1 = pd.DataFrame({'TemperatureB1': (TMS1B1, TMS2B1, TMS3B1, TMS4B1)}); 
lines = GB1.plot.line(); plt.title('Temparature Medie B1')
# Out:
# Text(0.5,1,'Temparature Medie B1')

# %%
GB2 = pd.DataFrame({'TemperatureB2': (TMS1B2, TMS2B2, TMS3B2, TMS4B2)})
lines = GB2.plot.line();  plt.title('Temparature Medie B2')
# Out:
# Text(0.5,1,'Temparature Medie B2')

# %%
GB3 = pd.DataFrame({'TemperatureB3': (TMS1B3, TMS2B3, TMS3B3, TMS4B3)})
lines = GB3.plot.line(); plt.title('Temparature Medie B3')
# Out:
# Text(0.5,1,'Temparature Medie B3')

# %%
GP = pd.DataFrame({'TemperatureB1': (TMS1B1, TMS2B1, TMS3B1, TMS4B1),
                  'TemperatureB2': (TMS1B2, TMS2B2, TMS3B2, TMS4B2),
                  'TemperatureB3': (TMS1B3, TMS2B3, TMS3B3, TMS4B3)
                   })

lines = GP.plot.line(); plt.title('Temparature Medie B1,2,3')
# Out:
# Text(0.5,1,'Temparature Medie B1,2,3')
